# %%
import pandas as pd

df = pd.read_csv('NBA_team_salarycap_2026.csv')

# %%
df.head()
# Out:
#    Rank Team Record  Players  Active Avg Age  Team Total Cap Allocations  \
# 0     1  OKC  64-18       15            24.6                   188057857
# 1     2  SAS  62-20       15            26.6                   183990669
# 2     3  DET  60-22       15            25.9                   193082507
# 3     4  BOS  56-26       15            26.1                   194526296
# 4     5  DEN  54-28       15            26.7                   200743895
#
#    Cap Space  All Active  Active Top 3  Dead Cap
# 0  -33410857   183713089      84935050   2296274
# 1  -29343669   176732468      83596620   7258201
# 2  -38435507   176545353      91019317   9337154
# 3  -39879296   187416191     135368714    469063
# 4  -46096895   187214031     124460081         0

# %%
import pandas as pd

df = pd.read_csv('NBA_team_salarycap_2026.csv')
numeric_df = df.select_dtypes(include=['number'])
corr_matrix = numeric_df.corr()
print(corr_matrix)
# Out:
#                                 Rank   Players  Active Avg Age  \
# Rank                        1.000000  0.275999       -0.287687
# Players                     0.275999  1.000000       -0.192561
# Active Avg Age             -0.287687 -0.192561        1.000000
# Team Total Cap Allocations -0.166277 -0.374227        0.492852
# Cap Space                   0.166277  0.374227       -0.492852
# All Active                 -0.526120 -0.494411        0.651914
# Active Top 3               -0.204880 -0.304866        0.620845
# Dead Cap                    0.493491  0.493105       -0.556995
#
#                             Team Total Cap Allocations  Cap Space  All Active  \
# Rank                                         -0.166277   0.166277   -0.526120
# Players                                      -0.374227   0.374227   -0.494411
# Active Avg Age                                0.492852  -0.492852    0.651914
# Team Total Cap Allocations                    1.000000  -1.000000    0.732055
# ...
