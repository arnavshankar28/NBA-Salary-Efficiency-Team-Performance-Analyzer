# %%
import pandas as pd

df = pd.read_csv('NBA_team_stats2.csv')

# %%
df.head()
# Out:
#     Rk                    Team   Age     W     L  PW  PL    MOV   SOS    SRS  \
# 0  1.0  Oklahoma City Thunder*  25.2  64.0  18.0  65  17  11.15 -0.11  11.04
# 1  2.0      San Antonio Spurs*  25.4  62.0  20.0  60  22   8.30 -0.03   8.28
# 2  3.0        Detroit Pistons*  26.1  60.0  22.0  60  22   8.16 -0.63   7.53
# 3  4.0         Boston Celtics*  26.9  56.0  26.0  59  23   7.70 -0.33   7.37
# 4  5.0        New York Knicks*  28.1  53.0  29.0  56  26   6.33 -0.28   6.05
#
#    ...  FT/FGA  Unnamed: 22  eFG%.1  TOV%.1  DRB%  FT/FGA.1  Unnamed: 27  \
# 0  ...   0.213          NaN   0.519    14.6  74.4     0.184          NaN
# 1  ...   0.215          NaN   0.522    11.5  77.3     0.180          NaN
# 2  ...   0.223          NaN   0.517    14.8  74.2     0.251          NaN
# 3  ...   0.167          NaN   0.523    11.4  75.7     0.189          NaN
# 4  ...   0.188          NaN   0.541    13.1  76.7     0.206          NaN
#
#                         Arena  Attend.  Attend./G
# 0               Paycom Center   764842      18203
# 1           Frost Bank Center   743129      18703
# 2        Little Caesars Arena   806422      19651
# 3                   TD Garden   785396      19156
# 4  Madison Square Garden (IV)   792480      19812
#
# [5 rows x 31 columns]

# %%
import pandas as pd

df = pd.read_csv('NBA_team_stats2.csv')
numeric_df = df.select_dtypes(include=['number'])
corr_matrix = numeric_df.corr()
print(corr_matrix)
# Out:
#                    Rk       Age         W         L        PW        PL  \
# Rk           1.000000 -0.242187 -0.953217  0.953217 -0.985853  0.985853
# Age         -0.242187  1.000000  0.319010 -0.319010  0.277493 -0.277493
# W           -0.953217  0.319010  1.000000 -1.000000  0.971560 -0.971560
# L            0.953217 -0.319010 -1.000000  1.000000 -0.971560  0.971560
# PW          -0.985853  0.277493  0.971560 -0.971560  1.000000 -1.000000
# PL           0.985853 -0.277493 -0.971560  0.971560 -1.000000  1.000000
# MOV         -0.984275  0.277850  0.972603 -0.972603  0.998778 -0.998778
# SOS          0.840617 -0.284685 -0.804109  0.804109 -0.825190  0.825190
# SRS         -0.982498  0.275110  0.972006 -0.972006  0.998210 -0.998210
# ORtg        -0.909497  0.361904  0.884938 -0.884938  0.908434 -0.908434
# DRtg         0.880864 -0.142115 -0.879174  0.879174 -0.906492  0.906492
# NRtg        -0.985173  0.275126  0.970968 -0.970968  0.998984 -0.998984
# Pace         0.377839 -0.359733 -0.378727  0.378727 -0.380801  0.380801
# FTr         -0.050804  0.053697  0.143564 -0.143564  0.072227 -0.072227
# 3PAr        -0.017646 -0.000098  0.043417 -0.043417  0.074288 -0.074288
# TS%         -0.646119  0.489480  0.695545 -0.695545  0.654256 -0.654256
# Unnamed: 17       NaN       NaN       NaN       NaN       NaN       NaN
# eFG%        -0.621785  0.510334  0.664236 -0.664236  0.616012 -0.616012
# TOV%         0.558316 -0.113692 -0.493438  0.493438 -0.525267  0.525267
# ORB%        -0.440616 -0.016308  0.374778 -0.374778  0.440377 -0.440377
# FT/FGA      -0.113762  0.064496  0.193829 -0.193829  0.149758 -0.149758
# Unnamed: 22       NaN       NaN       NaN       NaN       NaN       NaN
# eFG%.1       0.891094 -0.174609 -0.864107  0.864107 -0.893577  0.893577
# TOV%.1      -0.183049 -0.000555  0.273482 -0.273482  0.262840 -0.262840
# DRB%        -0.601737  0.154004  0.549823 -0.549823  0.563056 -0.563056
# FT/FGA.1     0.340680 -0.197362 -0.283545  0.283545 -0.332135  0.332135
# Unnamed: 27       NaN       NaN       NaN       NaN       NaN       NaN
# Attend.     -0.544907  0.173491  0.557868 -0.557868  0.553763 -0.553763
# Attend./G   -0.557870  0.194442  0.562964 -0.562964  0.559042 -0.559042
#
#                   MOV       SOS       SRS      ORtg  ...      ORB%    FT/FGA  \
# Rk          -0.984275  0.840617 -0.982498 -0.909497  ... -0.440616 -0.113762
# Age          0.277850 -0.284685  0.275110  0.361904  ... -0.016308  0.064496
# W            0.972603 -0.804109  0.972006  0.884938  ...  0.374778  0.193829
# L           -0.972603  0.804109 -0.972006 -0.884938  ... -0.374778 -0.193829
# PW           0.998778 -0.825190  0.998210  0.908434  ...  0.440377  0.149758
# PL          -0.998778  0.825190 -0.998210 -0.908434  ... -0.440377 -0.149758
# MOV          1.000000 -0.820681  0.999670  0.901514  ...  0.420928  0.155699
# SOS         -0.820681  1.000000 -0.805743 -0.784865  ... -0.495246 -0.128207
# SRS          0.999670 -0.805743  1.000000  0.899114  ...  0.414127  0.155470
# ORtg         0.901514 -0.784865  0.899114  1.000000  ...  0.404554  0.176844
# DRtg        -0.914524  0.710220 -0.916109 -0.650143  ... -0.370158 -0.099416
# NRtg         0.999752 -0.822155  0.999346  0.904577  ...  0.426063  0.151234
# Pace        -0.378491  0.423811 -0.373285 -0.408157  ... -0.374694  0.138467
# FTr          0.079514 -0.107037  0.077443  0.081861  ... -0.088750  0.965614
# 3PAr         0.080308  0.006024  0.083502  0.084536  ... -0.052819 -0.431723
# TS%          0.658213 -0.593139  0.655418  0.789822  ... -0.119623  0.302515
# Unnamed: 17       NaN       NaN       NaN       NaN  ...       NaN       NaN
# eFG%         0.618835 -0.579177  0.615249  0.746443  ... -0.109696  0.042110
# TOV%        -0.526783  0.264284 -0.534242 -0.542387  ...  0.086575 -0.102443
# ORB%         0.420928 -0.495246  0.414127  0.404554  ...  1.000000 -0.086352
# FT/FGA       0.155699 -0.128207  0.155470  0.176844  ... -0.086352  1.000000
# Unnamed: 22       NaN       NaN       NaN       NaN  ...       NaN       NaN
# eFG%.1      -0.896617  0.775013 -0.894637 -0.704197  ... -0.409308 -0.066128
# TOV%.1       0.267815 -0.131093  0.271788 -0.001351  ...  0.174577  0.074544
# DRB%         0.564505 -0.479661  0.563649  0.534836  ...  0.111687  0.056789
# FT/FGA.1    -0.346938  0.141846 -0.353092 -0.398424  ...  0.040521 -0.022766
# Unnamed: 27       NaN       NaN       NaN       NaN  ...       NaN       NaN
# Attend.      0.551938 -0.557462  0.547020  0.543380  ...  0.157151  0.322584
# Attend./G    0.555799 -0.564021  0.550741  0.559707  ...  0.185550  0.294459
#
#              Unnamed: 22    eFG%.1    TOV%.1      DRB%  FT/FGA.1  Unnamed: 27  \
# Rk                   NaN  0.891094 -0.183049 -0.601737  0.340680          NaN
# Age                  NaN -0.174609 -0.000555  0.154004 -0.197362          NaN
# W                    NaN -0.864107  0.273482  0.549823 -0.283545          NaN
# L                    NaN  0.864107 -0.273482 -0.549823  0.283545          NaN
# PW                   NaN -0.893577  0.262840  0.563056 -0.332135          NaN
# PL                   NaN  0.893577 -0.262840 -0.563056  0.332135          NaN
# MOV                  NaN -0.896617  0.267815  0.564505 -0.346938          NaN
# SOS                  NaN  0.775013 -0.131093 -0.479661  0.141846          NaN
# SRS                  NaN -0.894637  0.271788  0.563649 -0.353092          NaN
# ORtg                 NaN -0.704197 -0.001351  0.534836 -0.398424          NaN
# DRtg                 NaN  0.922704 -0.465167 -0.487774  0.241159          NaN
# NRtg                 NaN -0.897835  0.260263  0.562383 -0.350385          NaN
# Pace                 NaN  0.275417 -0.027081 -0.246349  0.122310          NaN
# FTr                  NaN -0.031551  0.069456  0.021241  0.065864          NaN
# 3PAr                 NaN  0.010055 -0.008188  0.135669 -0.195457          NaN
# TS%                  NaN -0.429365 -0.074543  0.462773 -0.374586          NaN
# Unnamed: 17          NaN       NaN       NaN       NaN       NaN          NaN
# eFG%                 NaN -0.418657 -0.103350  0.455619 -0.348224          NaN
# TOV%                 NaN  0.473113  0.045329 -0.345514  0.340676          NaN
# ORB%                 NaN -0.409308  0.174577  0.111687  0.040521          NaN
# FT/FGA               NaN -0.066128  0.074544  0.056789 -0.022766          NaN
# Unnamed: 22          NaN       NaN       NaN       NaN       NaN          NaN
# eFG%.1               NaN  1.000000 -0.207753 -0.451166  0.262565          NaN
# TOV%.1               NaN -0.207753  1.000000 -0.285302  0.393416          NaN
# DRB%                 NaN -0.451166 -0.285302  1.000000 -0.401981          NaN
# FT/FGA.1             NaN  0.262565  0.393416 -0.401981  1.000000          NaN
# Unnamed: 27          NaN       NaN       NaN       NaN       NaN          NaN
# Attend.              NaN -0.482686 -0.087357  0.615488 -0.249664          NaN
# Attend./G            NaN -0.482724 -0.122458  0.650331 -0.262265          NaN
#
#               Attend.  Attend./G
# Rk          -0.544907  -0.557870
# Age          0.173491   0.194442
# W            0.557868   0.562964
# L           -0.557868  -0.562964
# PW           0.553763   0.559042
# PL          -0.553763  -0.559042
# MOV          0.551938   0.555799
# SOS         -0.557462  -0.564021
# SRS          0.547020   0.550741
# ORtg         0.543380   0.559707
# DRtg        -0.464793  -0.456189
# NRtg         0.554099   0.558084
# Pace        -0.068102  -0.082284
# FTr          0.282151   0.259499
# 3PAr        -0.038201  -0.029309
# TS%          0.453089   0.458002
# Unnamed: 17       NaN        NaN
# eFG%         0.369587   0.384132
# TOV%        -0.362715  -0.359588
# ORB%         0.157151   0.185550
# FT/FGA       0.322584   0.294459
# Unnamed: 22       NaN        NaN
# eFG%.1      -0.482686  -0.482724
# TOV%.1      -0.087357  -0.122458
# DRB%         0.615488   0.650331
# FT/FGA.1    -0.249664  -0.262265
# Unnamed: 27       NaN        NaN
# Attend.      1.000000   0.991392
# Attend./G    0.991392   1.000000
#
# [29 rows x 29 columns]
